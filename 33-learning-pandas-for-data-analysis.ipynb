# %%
import pandas as pd
import sys

# Print Python version
print("sys.version:", sys.version)

# Print Pandas version
print("pandas version:", pd.__version__)
# Out:
# sys.version: 3.10.13 | packaged by conda-forge | (main, Dec 23 2023, 15:36:39) [GCC 12.3.0]
# pandas version: 2.2.0

# %% [markdown]
# # Input/Output(Reading and Writing)

# %%
# Create a dictionary with the data
data ={
    'Name': ['Praveen', 'Rahul', 'Priyanka'],
    'Age': [32,50,48],
    'City': ['Lucknow', 'Delhi', 'Mumbai']
}
# Create the DataFrame using the dictionary
df = pd.DataFrame(data)
# Printing the DataFrame
df
# Out:
#        Name  Age     City
# 0   Praveen   32  Lucknow
# 1     Rahul   50    Delhi
# 2  Priyanka   48   Mumbai

# %%
# Install pkg pyarrow OR fastparquet

# %%
# Read the dataset from the Parquet file
df = pd.read_parquet("/kaggle/input/combined-flights-2022/Combined_Flights_2022.parquet")

# Set option to display a maximum of 500 columns
pd.set_option('display.max_columns', 500)

# Check the shape of the DataFrame
print("Shape of the DataFrame:", df.shape)
# Out:
# Shape of the DataFrame: (4078318, 61)

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
# 2      False     False        1529   1514.0              0.0     -15.0
# 3      False     False        1435   1430.0              0.0      -5.0
# 4      False     False        1135   1135.0              0.0       0.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
# Display the last 5 rows of the DataFrame
df.tail()
# Out:
#        FlightDate            Airline Origin Dest  Cancelled  Diverted  \
# 590537 2022-03-31  Republic Airlines    MSY  EWR      False      True
# 590538 2022-03-17  Republic Airlines    CLT  EWR       True     False
# 590539 2022-03-08  Republic Airlines    ALB  ORD      False     False
# 590540 2022-03-25  Republic Airlines    EWR  PIT      False      True
# 590541 2022-03-07  Republic Airlines    EWR  RDU      False      True
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 590537        1949   2014.0             25.0      25.0    234.0
# 590538        1733   1817.0             44.0      44.0      NaN
# 590539        1700   2318.0            378.0     378.0     59.0
# 590540        2129   2322.0            113.0     113.0    939.0
# 590541        1154   1148.0              0.0      -6.0   1556.0
#
#         ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  \
# ...

# %%
# Randomly sample 5 rows from the DataFrame
df.sample(5)
# Out:
#        FlightDate                Airline Origin Dest  Cancelled  Diverted  \
# 120803 2022-05-04  United Air Lines Inc.    PDX  DEN      False     False
# 457476 2022-06-14      Endeavor Air Inc.    BOS  MKE      False     False
# 993    2022-06-28            Comair Inc.    PHL  AVL      False     False
# 59517  2022-01-26   Delta Air Lines Inc.    RDU  MSP      False     False
# 187836 2022-07-22   Delta Air Lines Inc.    ATL  ICT      False     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 120803         530    524.0              0.0      -6.0    857.0
# 457476        2025   2039.0             14.0      14.0   2218.0
# 993           1537   1545.0              8.0       8.0   1728.0
# 59517          625    612.0              0.0     -13.0    758.0
# 187836        1540   1610.0             30.0      30.0   1720.0
#
#         ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  \
# ...

# %%
# Randomly sample 3 rows from the DataFrame with a random state of 42
df.sample(3, random_state=42)
# Out:
#        FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 324021 2022-03-19   SkyWest Airlines Inc.    ASE  DEN      False     False
# 34739  2022-02-16   SkyWest Airlines Inc.    TYS  DEN      False     False
# 304494 2022-01-18  American Airlines Inc.    LAX  OGG      False     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 324021        1831   1826.0              0.0      -5.0   1923.0
# 34739         1605   1605.0              0.0       0.0   1812.0
# 304494        1719   1714.0              0.0      -5.0   2052.0
#
#         ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  Distance  \
# 324021              0.0     31.0            62.0               57.0     125.0
# 34739              35.0    194.0           212.0              247.0    1162.0
# 304494              3.0    314.0           330.0              338.0    2486.0
#
#         Year  Quarter  Month  DayofMonth  DayOfWeek Marketing_Airline_Network  \
# ...

# %%
# Randomly sample 10% of the DataFrame with a random state of 529
df.sample(frac=0.1, random_state=529)
# Out:
#        FlightDate                      Airline Origin Dest  Cancelled  \
# 103009 2022-01-07                    Envoy Air    DCA  RDU      False
# 505955 2022-06-10       American Airlines Inc.    PHX  DFW      False
# 162428 2022-07-03         Delta Air Lines Inc.    ATL  MCO      False
# 328714 2022-02-21       Frontier Airlines Inc.    IAH  MCO      False
# 447780 2022-03-01       Southwest Airlines Co.    DCA  MDW      False
# ...           ...                          ...    ...  ...        ...
# 579190 2022-07-31       Southwest Airlines Co.    BWI  ORF      False
# 191950 2022-01-04       Southwest Airlines Co.    AUS  DAL      False
# 185257 2022-02-08       American Airlines Inc.    PHX  LAX      False
# 379494 2022-03-31        United Air Lines Inc.    RSW  SFO      False
# 237876 2022-04-01  Capital Cargo International    SBY  PHL      False
#
#         Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# ...

# %%
num_rows_shape = df.shape[0]  # Using df.shape[0]
num_rows_len = len(df)         # Using len(df)

num_rows_shape, num_rows_len
# Out:
# (4078318, 4078318)

# %% [markdown]
# # Subsetting A DataFrame

# %%
# Select columns 'FlightDate', 'Airline', and 'Origin'
df[['FlightDate', 'Airline', 'Origin']]
# Out:
#        FlightDate                                    Airline Origin
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO
# ...           ...                                        ...    ...
# 590537 2022-03-31                          Republic Airlines    MSY
# 590538 2022-03-17                          Republic Airlines    CLT
# 590539 2022-03-08                          Republic Airlines    ALB
# 590540 2022-03-25                          Republic Airlines    EWR
# 590541 2022-03-07                          Republic Airlines    EWR
#
# [4078318 rows x 3 columns]

# %%
# Select the first five columns of the DataFrame
df[df.columns[:5]]
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 590537 2022-03-31                          Republic Airlines    MSY  EWR
# 590538 2022-03-17                          Republic Airlines    CLT  EWR
# 590539 2022-03-08                          Republic Airlines    ALB  ORD
# 590540 2022-03-25                          Republic Airlines    EWR  PIT
# 590541 2022-03-07                          Republic Airlines    EWR  RDU
#
#         Cancelled
# 0           False
# 1           False
# 2           False
# ...

# %%
# Select the last five columns of the DataFrame
df[df.columns[-5:]]
# Out:
#         ArrDel15  ArrivalDelayGroups ArrTimeBlk  DistanceGroup  \
# 0            0.0                -2.0  1200-1259              1
# 1            0.0                -1.0  0800-0859              2
# 2            0.0                -1.0  1600-1659              2
# 3            0.0                -2.0  1600-1659              2
# 4            0.0                 0.0  1200-1259              2
# ...          ...                 ...        ...            ...
# 590537       NaN                 NaN  2300-2359              5
# 590538       NaN                 NaN  1900-1959              3
# 590539       1.0                12.0  1800-1859              3
# 590540       NaN                 NaN  2200-2259              2
# 590541       NaN                 NaN  1300-1359              2
#
#         DivAirportLandings
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# ...

# %%
# Filter columns containing 'Time'
[c for c in df.columns if 'Time' in c]
# Out:
# ['CRSDepTime',
#  'DepTime',
#  'ArrTime',
#  'AirTime',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
#  'DepTimeBlk',
#  'CRSArrTime',
#  'ArrTimeBlk']

# %%
# Select columns containing 'Time'
df[[c for c in df.columns if 'Time' in c]]
# Out:
#         CRSDepTime  DepTime  ArrTime  AirTime  CRSElapsedTime  \
# 0             1133   1123.0   1228.0     40.0            72.0
# 1              732    728.0    848.0     55.0            77.0
# 2             1529   1514.0   1636.0     47.0            70.0
# 3             1435   1430.0   1547.0     57.0            90.0
# 4             1135   1135.0   1251.0     49.0            70.0
# ...            ...      ...      ...      ...             ...
# 590537        1949   2014.0    234.0      NaN           185.0
# 590538        1733   1817.0      NaN      NaN           129.0
# 590539        1700   2318.0     59.0    135.0           158.0
# 590540        2129   2322.0    939.0      NaN            86.0
# 590541        1154   1148.0   1556.0      NaN            99.0
#
#         ActualElapsedTime DepTimeBlk  CRSArrTime ArrTimeBlk
# 0                    65.0  1100-1159        1245  1200-1259
# 1                    80.0  0700-0759         849  0800-0859
# ...

# %%
# Select columns of integer data type
df.select_dtypes('int')

# Select columns of datetime data type
df.select_dtypes('datetime64')

# Select columns of boolean data type
df.select_dtypes('bool')

# Select columns of object data type
df.select_dtypes('object')
# Out:
#                                           Airline Origin Dest  \
# 0       Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1       Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2       Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3       Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4       Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...                                           ...    ...  ...
# 590537                          Republic Airlines    MSY  EWR
# 590538                          Republic Airlines    CLT  EWR
# 590539                          Republic Airlines    ALB  ORD
# 590540                          Republic Airlines    EWR  PIT
# 590541                          Republic Airlines    EWR  RDU
#
#        Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                             UA                            UA_CODESHARE
# ...

# %%
# Select the 'Airline' column as Series
df['Airline']
# Out:
# 0         Commutair Aka Champlain Enterprises, Inc.
# 1         Commutair Aka Champlain Enterprises, Inc.
# 2         Commutair Aka Champlain Enterprises, Inc.
# 3         Commutair Aka Champlain Enterprises, Inc.
# 4         Commutair Aka Champlain Enterprises, Inc.
#                             ...
# 590537                            Republic Airlines
# 590538                            Republic Airlines
# 590539                            Republic Airlines
# 590540                            Republic Airlines
# 590541                            Republic Airlines
# Name: Airline, Length: 4078318, dtype: object

# %%
# Select the 'Airline' column as a DataFrame
df[['Airline']]
# Out:
#                                           Airline
# 0       Commutair Aka Champlain Enterprises, Inc.
# 1       Commutair Aka Champlain Enterprises, Inc.
# 2       Commutair Aka Champlain Enterprises, Inc.
# 3       Commutair Aka Champlain Enterprises, Inc.
# 4       Commutair Aka Champlain Enterprises, Inc.
# ...                                           ...
# 590537                          Republic Airlines
# 590538                          Republic Airlines
# 590539                          Republic Airlines
# 590540                          Republic Airlines
# 590541                          Republic Airlines
#
# [4078318 rows x 1 columns]

# %% [markdown]
# # Filtering Rows
#
# `df.loc[]` and `df.iloc[]`

# %% [markdown]
# # iloc

# %%
# Access a specific value at row 1, column 6
df.iloc[1, 6]
# Out:
# 732

# %%
# Access the first 3 rows and the first 5 columns
df.iloc[:3, :5]
# Out:
#   FlightDate                                    Airline Origin Dest  Cancelled
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN      False
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH      False
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False

# %%
# Access the values at row 5
df.iloc[5]
# Out:
# FlightDate                                  2022-04-04 00:00:00
# Airline               Commutair Aka Champlain Enterprises, Inc.
# Origin                                                      DEN
# Dest                                                        TUL
# Cancelled                                                 False
#                                         ...
# ArrDel15                                                    0.0
# ArrivalDelayGroups                                         -1.0
# ArrTimeBlk                                            1200-1259
# DistanceGroup                                                 3
# DivAirportLandings                                            0
# Name: 5, Length: 61, dtype: object

# %%
# Access the values at row 5 as a DataFrame
df.iloc[[5]]
# Out:
#   FlightDate                                    Airline Origin Dest  \
# 5 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DEN  TUL
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 5      False     False         955    952.0              0.0      -3.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# 5   1238.0              0.0     77.0           105.0              106.0
#
#    Distance  Year  Quarter  Month  DayofMonth  DayOfWeek  \
# 5     541.0  2022        2      4           4          1
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 5                        UA                            UA_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  \
# 5                     19977                          UA
#
#    Flight_Number_Marketing_Airline Operating_Airline  \
# 5                             4294                C5
#
# ...

# %%
# Access the values in the second column
df.iloc[:, 1]
# Out:
# 0         Commutair Aka Champlain Enterprises, Inc.
# 1         Commutair Aka Champlain Enterprises, Inc.
# 2         Commutair Aka Champlain Enterprises, Inc.
# 3         Commutair Aka Champlain Enterprises, Inc.
# 4         Commutair Aka Champlain Enterprises, Inc.
#                             ...
# 590537                            Republic Airlines
# 590538                            Republic Airlines
# 590539                            Republic Airlines
# 590540                            Republic Airlines
# 590541                            Republic Airlines
# Name: Airline, Length: 4078318, dtype: object

# %%
# Access the values of the first 3 rows and the first 3 columns
df.iloc[:3, [0, 1, 2]]
# Out:
#   FlightDate                                    Airline Origin
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO

# %%
# Access the values of the first 3 rows and the first 5 columns
df.iloc[:3, 0:5]
# Out:
#   FlightDate                                    Airline Origin Dest  Cancelled
# 0 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN      False
# 1 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH      False
# 2 2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False

# %% [markdown]
# # loc

# %%
# Select specific columns 'Airline', 'Origin', 'Dest', and 'Cancelled'
df.loc[:, ['Airline', 'Origin', 'Dest', 'Cancelled']]
# Out:
#                                           Airline Origin Dest  Cancelled
# 0       Commutair Aka Champlain Enterprises, Inc.    GJT  DEN      False
# 1       Commutair Aka Champlain Enterprises, Inc.    HRL  IAH      False
# 2       Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False
# 3       Commutair Aka Champlain Enterprises, Inc.    IAH  GPT      False
# 4       Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False
# ...                                           ...    ...  ...        ...
# 590537                          Republic Airlines    MSY  EWR      False
# 590538                          Republic Airlines    CLT  EWR       True
# 590539                          Republic Airlines    ALB  ORD      False
# 590540                          Republic Airlines    EWR  PIT      False
# 590541                          Republic Airlines    EWR  RDU      False
#
# [4078318 rows x 4 columns]

# %%
# Select specific columns 'Airline', 'Origin', 'Dest', and 'Cancelled' for rows up to index 3
df.iloc[:4, df.columns.isin(['Airline', 'Origin', 'Dest', 'Cancelled'])]
# Out:
#                                      Airline Origin Dest  Cancelled
# 0  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN      False
# 1  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH      False
# 2  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN      False
# 3  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT      False

# %%
# Select rows where the 'Airline' is 'Spirit Air Lines'
df.loc[df['Airline'] == 'Spirit Air Lines']
# Out:
#        FlightDate           Airline Origin Dest  Cancelled  Diverted  \
# 407040 2022-04-01  Spirit Air Lines    FLL  ORD       True     False
# 407041 2022-04-02  Spirit Air Lines    FLL  ORD       True     False
# 407042 2022-04-03  Spirit Air Lines    FLL  ORD      False     False
# 407043 2022-04-04  Spirit Air Lines    FLL  ORD      False     False
# 407044 2022-04-05  Spirit Air Lines    FLL  ORD      False     False
# ...           ...               ...    ...  ...        ...       ...
# 142478 2022-03-27  Spirit Air Lines    EWR  LAS      False     False
# 142479 2022-03-28  Spirit Air Lines    EWR  LAS      False     False
# 142480 2022-03-29  Spirit Air Lines    EWR  LAS      False     False
# 142481 2022-03-30  Spirit Air Lines    EWR  LAS      False     False
# 142482 2022-03-31  Spirit Air Lines    EWR  LAS       True     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 407040        2025      NaN              NaN       NaN      NaN
# ...

# %%
# Select rows where the 'Airline' is 'Spirit Air Lines' and the 'FlightDate' is '2022-04-01'
df.loc[(df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-04-01')]
# Out:
#        FlightDate           Airline Origin Dest  Cancelled  Diverted  \
# 407040 2022-04-01  Spirit Air Lines    FLL  ORD       True     False
# 407070 2022-04-01  Spirit Air Lines    ORD  FLL      False     False
# 407100 2022-04-01  Spirit Air Lines    ORD  FLL      False     False
# 407130 2022-04-01  Spirit Air Lines    FLL  ORD      False     False
# 407183 2022-04-01  Spirit Air Lines    CLT  LAS      False     False
# ...           ...               ...    ...  ...        ...       ...
# 425552 2022-04-01  Spirit Air Lines    CLT  FLL      False     False
# 425582 2022-04-01  Spirit Air Lines    FLL  CLT      False     False
# 425612 2022-04-01  Spirit Air Lines    DTW  MSY      False     False
# 425633 2022-04-01  Spirit Air Lines    MSY  ORD      False     False
# 425663 2022-04-01  Spirit Air Lines    EWR  LAS      False     False
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 407040        2025      NaN              NaN       NaN      NaN
# ...

# %%
# Select rows where the 'Airline' is not 'Spirit Air Lines' and the 'FlightDate' is '2022-04-01'
df.loc[~((df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-04-01'))]
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 590537 2022-03-31                          Republic Airlines    MSY  EWR
# 590538 2022-03-17                          Republic Airlines    CLT  EWR
# 590539 2022-03-08                          Republic Airlines    ALB  ORD
# 590540 2022-03-25                          Republic Airlines    EWR  PIT
# 590541 2022-03-07                          Republic Airlines    EWR  RDU
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %%
# Alternative syntax for the previous operation
df.loc[~((df['Airline'] == 'Spirit Air Lines') & (df['FlightDate'] == '2022-04-01'))]
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 590537 2022-03-31                          Republic Airlines    MSY  EWR
# 590538 2022-03-17                          Republic Airlines    CLT  EWR
# 590539 2022-03-08                          Republic Airlines    ALB  ORD
# 590540 2022-03-25                          Republic Airlines    EWR  PIT
# 590541 2022-03-07                          Republic Airlines    EWR  RDU
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %% [markdown]
# # Filtering Using Query

# %%
# Query the DataFrame for flights with departure time greater than 1130 and origin at 'DRO'
df.query('(DepTime > 1130) and (Origin == "DRO")')
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 531    2022-04-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 533    2022-04-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 1003   2022-04-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 445339 2022-03-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 445977 2022-03-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 445986 2022-03-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 446617 2022-03-01  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 446626 2022-03-01  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %%
# Define variables for conditions
min_time = 1130
origin = 'DRO'

# Query the DataFrame using variables for conditions
df.query('(DepTime > @min_time) and (Origin == @origin)')
# Out:
#        FlightDate                                    Airline Origin Dest  \
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 531    2022-04-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 533    2022-04-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 1003   2022-04-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...           ...                                        ...    ...  ...
# 445339 2022-03-03  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 445977 2022-03-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 445986 2022-03-02  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 446617 2022-03-01  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 446626 2022-03-01  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#         Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# ...

# %% [markdown]
# # Summarizing Data

# %%
# Calculate the sum of departure times
df['DepTime'].sum()

# Calculate the mean of departure times
df['DepTime'].mean()

# Count the number of non-null departure times
df['DepTime'].count()

# Calculate the median of departure times
df['DepTime'].median()

# Calculate the mode of departure times
df['DepTime'].mode()

# Calculate the standard deviation of departure times
df['DepTime'].std()

# Find the minimum departure time
df['DepTime'].min()

# Find the maximum departure time
df['DepTime'].max()

# Calculate the variance of departure times
df['DepTime'].var()

# Calculate the 50th percentile (median) of departure times
df['DepTime'].quantile(0.5)

# Calculate the 25th, 50th, and 75th percentiles of departure times
df['DepTime'].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25     917.0
# 0.50    1325.0
# 0.75    1744.0
# Name: DepTime, dtype: float64

# %%
# Calculate the mean of 'DepTime', 'DepDelay', 'ArrTime', and 'ArrDelay'
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].mean()
# Out:
# DepTime     1334.373931
# DepDelay      13.090487
# ArrTime     1457.886018
# ArrDelay       7.528486
# dtype: float64

# %%
# Calculate the mean, minimum, and maximum of 'DepTime', 'DepDelay', 'ArrTime', and 'ArrDelay'
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg(['mean', 'min', 'max'])
# Out:
#           DepTime     DepDelay      ArrTime     ArrDelay
# mean  1334.373931    13.090487  1457.886018     7.528486
# min      1.000000   -78.000000     1.000000  -100.000000
# max   2400.000000  7223.000000  2400.000000  7232.000000

# %%
# Calculate the minimum and maximum of 'DepTime' and 'ArrTime', and the mean of 'DepDelay'
df[['DepTime', 'DepDelay', 'ArrTime', 'ArrDelay']].agg({
    "DepTime": ['min', 'max'],
    "DepDelay": ['mean'],
    "ArrTime": ['min', 'max']
})
# Out:
#       DepTime   DepDelay  ArrTime
# min       1.0        NaN      1.0
# max    2400.0        NaN   2400.0
# mean      NaN  13.090487      NaN

# %% [markdown]
# # Summarizing Categorical Variables

# %%
# Get the unique values in the 'Airline' column
df['Airline'].unique()
# Out:
# array(['Commutair Aka Champlain Enterprises, Inc.',
#        'GoJet Airlines, LLC d/b/a United Express',
#        'Air Wisconsin Airlines Corp', 'Mesa Airlines Inc.',
#        'Southwest Airlines Co.', 'Republic Airlines', 'Endeavor Air Inc.',
#        'American Airlines Inc.', 'Capital Cargo International',
#        'SkyWest Airlines Inc.', 'Alaska Airlines Inc.', 'JetBlue Airways',
#        'Delta Air Lines Inc.', 'Frontier Airlines Inc.', 'Allegiant Air',
#        'Hawaiian Airlines Inc.', 'Envoy Air', 'Spirit Air Lines',
#        'Comair Inc.', 'Horizon Air', 'United Air Lines Inc.'],
#       dtype=object)

# %%
# Count the number of unique values in the 'Airline' column
df['Airline'].nunique()
# Out:
# 21

# %%
# Count the frequency of each unique value in the 'Airline' column
df['Airline'].value_counts()
# Out:
# Airline
# Southwest Airlines Co.                       731925
# Delta Air Lines Inc.                         512114
# American Airlines Inc.                       495953
# SkyWest Airlines Inc.                        440807
# United Air Lines Inc.                        352009
# Republic Airlines                            197881
# JetBlue Airways                              156793
# Envoy Air                                    150758
# Endeavor Air Inc.                            142624
# Comair Inc.                                  135884
# Alaska Airlines Inc.                         129510
# Spirit Air Lines                             129208
# Frontier Airlines Inc.                        86557
# Allegiant Air                                 73504
# Mesa Airlines Inc.                            71972
# Horizon Air                                   56320
# Capital Cargo International                   52827
# Commutair Aka Champlain Enterprises, Inc.     44367
# ...

# %%
# Count the frequency of each unique value in the 'Airline' column
df['Airline'].value_counts(normalize=True)
# Out:
# Airline
# Southwest Airlines Co.                       0.179467
# Delta Air Lines Inc.                         0.125570
# American Airlines Inc.                       0.121607
# SkyWest Airlines Inc.                        0.108085
# United Air Lines Inc.                        0.086312
# Republic Airlines                            0.048520
# JetBlue Airways                              0.038446
# Envoy Air                                    0.036966
# Endeavor Air Inc.                            0.034971
# Comair Inc.                                  0.033319
# Alaska Airlines Inc.                         0.031756
# Spirit Air Lines                             0.031682
# Frontier Airlines Inc.                       0.021224
# Allegiant Air                                0.018023
# Mesa Airlines Inc.                           0.017647
# Horizon Air                                  0.013810
# Capital Cargo International                  0.012953
# ...

# %%
# Count the frequency of each unique value in the 'Airline' column and display as percentages
df['Airline'].value_counts(normalize=True).mul(100).round(2).astype(str) + '%'
# Out:
# Airline
# Southwest Airlines Co.                       17.95%
# Delta Air Lines Inc.                         12.56%
# American Airlines Inc.                       12.16%
# SkyWest Airlines Inc.                        10.81%
# United Air Lines Inc.                         8.63%
# Republic Airlines                             4.85%
# JetBlue Airways                               3.84%
# Envoy Air                                      3.7%
# Endeavor Air Inc.                              3.5%
# Comair Inc.                                   3.33%
# Alaska Airlines Inc.                          3.18%
# Spirit Air Lines                              3.17%
# Frontier Airlines Inc.                        2.12%
# Allegiant Air                                  1.8%
# Mesa Airlines Inc.                            1.76%
# Horizon Air                                   1.38%
# Capital Cargo International                    1.3%
# Commutair Aka Champlain Enterprises, Inc.     1.09%
# ...

# %%
# Count the frequency of each unique combination of 'Airline' and 'Origin' columns
df[['Airline', 'Origin']].value_counts().reset_index()
# Out:
#                                         Airline Origin   count
# 0                          Delta Air Lines Inc.    ATL  120919
# 1                        American Airlines Inc.    DFW   81239
# 2                        American Airlines Inc.    CLT   57914
# 3                         United Air Lines Inc.    DEN   46489
# 4                        Southwest Airlines Co.    DEN   45398
# ...                                         ...    ...     ...
# 2189                     Frontier Airlines Inc.    ICT       1
# 2190                         Mesa Airlines Inc.    MDT       1
# 2191                Air Wisconsin Airlines Corp    FWA       1
# 2192  Commutair Aka Champlain Enterprises, Inc.    DSM       1
# 2193   GoJet Airlines, LLC d/b/a United Express    MKE       1
#
# [2194 rows x 3 columns]

# %% [markdown]
# # Advanced Column Methods

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
# Create a DataFrame
dfnew = pd.DataFrame({'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
                   'Score': [85, 70, 92, 80, 78]})

# Rank the DataFrame based on the 'Score' column
dfnew['Rank'] = dfnew['Score'].rank(ascending=False)  # By default, ascending=True ranks from lowest to highest
print(dfnew)
# Out:
#       Name  Score  Rank
# 0    Alice     85   2.0
# 1      Bob     70   5.0
# 2  Charlie     92   1.0
# 3    David     80   3.0
# 4    Emily     78   4.0

# %%
# Compute rank of each element in the 'CRSDepTime' column
df[['CRSDepTime']].rank()
# Out:
#         CRSDepTime
# 0        1607887.5
# 1         595750.5
# 2        2549367.0
# 3        2344374.5
# 4        1615667.5
# ...            ...
# 590537   3576231.5
# 590538   3053676.0
# 590539   2916510.0
# 590540   3877928.5
# 590541   1678988.0
#
# [4078318 rows x 1 columns]

# %%
# Compute rank of each element in the 'CRSDepTime' column using dense method
df[['CRSDepTime']].rank(method='dense')
# Out:
#         CRSDepTime
# 0            574.0
# 1            333.0
# 2            810.0
# 3            756.0
# 4            576.0
# ...            ...
# 590537      1070.0
# 590538       934.0
# 590539       901.0
# 590540      1170.0
# 590541       595.0
#
# [4078318 rows x 1 columns]

# %%
# Compute rank of each element in the 'CRSDepTime' column using first method
df[['CRSDepTime']].rank(method='first')
# Out:
#         CRSDepTime
# 0        1607043.0
# 1         594869.0
# 2        2547637.0
# 3        2338954.0
# 4        1610842.0
# ...            ...
# 590537   3576966.0
# 590538   3054522.0
# 590539   2925978.0
# 590540   3879124.0
# 590541   1679890.0
#
# [4078318 rows x 1 columns]

# %%
# Shift the 'CRSDepTime' column by 1 position
df[['CRSDepTime']].shift(1)
# Out:
#         CRSDepTime
# 0              NaN
# 1           1133.0
# 2            732.0
# 3           1529.0
# 4           1435.0
# ...            ...
# 590537      2035.0
# 590538      1949.0
# 590539      1733.0
# 590540      1700.0
# 590541      2129.0
#
# [4078318 rows x 1 columns]

# %%
# Shift the 'CRSDepTime' column by 3 positions
df[['CRSDepTime']].shift(3)
# Out:
#         CRSDepTime
# 0              NaN
# 1              NaN
# 2              NaN
# 3           1133.0
# 4            732.0
# ...            ...
# 590537      1750.0
# 590538      1829.0
# 590539      2035.0
# 590540      1949.0
# 590541      1733.0
#
# [4078318 rows x 1 columns]

# %%
# Shift the 'CRSDepTime' column by 3 positions with fill value 0
df[['CRSDepTime']].shift(3, fill_value=0)
# Out:
#         CRSDepTime
# 0                0
# 1                0
# 2                0
# 3             1133
# 4              732
# ...            ...
# 590537        1750
# 590538        1829
# 590539        2035
# 590540        1949
# 590541        1733
#
# [4078318 rows x 1 columns]

# %%
# Compute cumulative sum of the 'CRSDepTime' column
df[['CRSDepTime']].cumsum()
# Out:
#         CRSDepTime
# 0             1133
# 1             1865
# 2             3394
# 3             4829
# 4             5964
# ...            ...
# 590537  5422470512
# 590538  5422472245
# 590539  5422473945
# 590540  5422476074
# 590541  5422477228
#
# [4078318 rows x 1 columns]

# %%
# Compute cumulative maximum of the 'CRSDepTime' column
df[['CRSDepTime']].cummax()
# Out:
#         CRSDepTime
# 0             1133
# 1             1133
# 2             1529
# 3             1529
# 4             1529
# ...            ...
# 590537        2359
# 590538        2359
# 590539        2359
# 590540        2359
# 590541        2359
#
# [4078318 rows x 1 columns]

# %%
# Compute cumulative minimum of the 'CRSDepTime' column
df[['CRSDepTime']].cummin()
# Out:
#         CRSDepTime
# 0             1133
# 1              732
# 2              732
# 3              732
# 4              732
# ...            ...
# 590537           1
# 590538           1
# 590539           1
# 590540           1
# 590541           1
#
# [4078318 rows x 1 columns]

# %%
# Compute rolling mean of the 'CRSDepTime' column with window size 5
df[['CRSDepTime']].rolling(window=5).mean()
# Out:
#         CRSDepTime
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4           1192.8
# ...            ...
# 590537      1796.2
# 590538      1859.2
# 590539      1849.2
# 590540      1909.2
# 590541      1733.0
#
# [4078318 rows x 1 columns]

# %%
# Clip values in the 'CRSDepTime' column to be within a specific range
df[['CRSDepTime']].clip()
# Out:
#         CRSDepTime
# 0             1133
# 1              732
# 2             1529
# 3             1435
# 4             1135
# ...            ...
# 590537        1949
# 590538        1733
# 590539        1700
# 590540        2129
# 590541        1154
#
# [4078318 rows x 1 columns]

# %%
# Clip values in the 'CRSDepTime' column to be within the range [1000, 2000]
df[['CRSDepTime']].clip(1000, 2000)
# Out:
#         CRSDepTime
# 0             1133
# 1             1000
# 2             1529
# 3             1435
# 4             1135
# ...            ...
# 590537        1949
# 590538        1733
# 590539        1700
# 590540        2000
# 590541        1154
#
# [4078318 rows x 1 columns]

# %% [markdown]
# # Groupby Methods

# %%
# Compute mean departure delay for each airline
df.groupby('Airline')[['DepDelay']].mean()
# Out:
#                                             DepDelay
# Airline
# Air Wisconsin Airlines Corp                 7.913244
# Alaska Airlines Inc.                        5.925950
# Allegiant Air                              19.061569
# American Airlines Inc.                     14.876556
# Capital Cargo International                 6.044430
# Comair Inc.                                12.693968
# Commutair Aka Champlain Enterprises, Inc.  12.093640
# Delta Air Lines Inc.                       11.398599
# Endeavor Air Inc.                           9.696390
# Envoy Air                                   6.883448
# Frontier Airlines Inc.                     20.052761
# GoJet Airlines, LLC d/b/a United Express   16.741980
# Hawaiian Airlines Inc.                      6.612163
# Horizon Air                                 5.892804
# JetBlue Airways                            26.009890
# Mesa Airlines Inc.                         15.714753
# Republic Airlines                          10.811487
# ...

# %%
# Compute mean, minimum, and maximum departure delay for each airline
df.groupby('Airline')[['DepDelay']].agg(['mean', 'min', 'max'])
# Out:
#                                             DepDelay
#                                                 mean   min     max
# Airline
# Air Wisconsin Airlines Corp                 7.913244 -30.0  1355.0
# Alaska Airlines Inc.                        5.925950 -63.0   915.0
# Allegiant Air                              19.061569 -37.0  1917.0
# American Airlines Inc.                     14.876556 -35.0  2994.0
# Capital Cargo International                 6.044430 -34.0  1512.0
# Comair Inc.                                12.693968 -49.0  1607.0
# Commutair Aka Champlain Enterprises, Inc.  12.093640 -27.0  1464.0
# Delta Air Lines Inc.                       11.398599 -38.0  1287.0
# Endeavor Air Inc.                           9.696390 -34.0  1973.0
# Envoy Air                                   6.883448 -29.0  5327.0
# Frontier Airlines Inc.                     20.052761 -40.0  1288.0
# GoJet Airlines, LLC d/b/a United Express   16.741980 -43.0  1220.0
# ...

# %%
# Compute mean, minimum, and maximum departure delay and arrival delay for each airline
df_agg = df.groupby('Airline')[['DepDelay', 'ArrDelay']].agg(['mean', 'min', 'max'])

# %%
# Flatten the multi-level column index
df_agg.columns = df_agg.columns.to_flat_index()

# %%
# Rename the columns with a joined string of original column names
df_agg.columns = ['_'.join(c) for c in df_agg.columns]

# %% [markdown]
# # New Columns

# %%
# Create a new column 'DepTime_2' by dividing 'DepTime' by 60
df['DepTime_2'] = df['DepTime'] / 60

# %%
# Use the 'assign' method to create a new column 'DepTime_New' by dividing 'DepTime' by 2
df = df.assign(DepTime_New = df['DepTime'] / 2)

# %% [markdown]
# # Sorting Data

# %%
# Sort the DataFrame by 'ArrDelay' column in ascending order
df.sort_values('ArrDelay')
# Out:
#        FlightDate               Airline Origin Dest  Cancelled  Diverted  \
# 412626 2022-01-20       JetBlue Airways    STT  EWR      False     False
# 268256 2022-03-30       JetBlue Airways    STT  JFK      False     False
# 398369 2022-01-22       JetBlue Airways    STT  JFK      False     False
# 284876 2022-04-12  Delta Air Lines Inc.    SAN  ATL      False     False
# 583512 2022-05-12     Republic Airlines    LGA  IAH      False     False
# ...           ...                   ...    ...  ...        ...       ...
# 590535 2022-03-31     Republic Airlines    EWR  PIT       True     False
# 590537 2022-03-31     Republic Airlines    MSY  EWR      False      True
# 590538 2022-03-17     Republic Airlines    CLT  EWR       True     False
# 590540 2022-03-25     Republic Airlines    EWR  PIT      False      True
# 590541 2022-03-07     Republic Airlines    EWR  RDU      False      True
#
#         CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# ...

# %%
# Sort the selected columns 'FlightDate', 'Airline', 'ArrDelay' by 'ArrDelay' column in ascending order
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay')
# Out:
#        FlightDate               Airline  ArrDelay
# 412626 2022-01-20       JetBlue Airways    -100.0
# 268256 2022-03-30       JetBlue Airways     -95.0
# 398369 2022-01-22       JetBlue Airways     -91.0
# 284876 2022-04-12  Delta Air Lines Inc.     -86.0
# 583512 2022-05-12     Republic Airlines     -81.0
# ...           ...                   ...       ...
# 590535 2022-03-31     Republic Airlines       NaN
# 590537 2022-03-31     Republic Airlines       NaN
# 590538 2022-03-17     Republic Airlines       NaN
# 590540 2022-03-25     Republic Airlines       NaN
# 590541 2022-03-07     Republic Airlines       NaN
#
# [4078318 rows x 3 columns]

# %%
# Sort the selected columns 'FlightDate', 'Airline', 'ArrDelay' by 'ArrDelay' column in descending order
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False)
# Out:
#        FlightDate                 Airline  ArrDelay
# 249863 2022-05-23       Republic Airlines    7232.0
# 553561 2022-06-18               Envoy Air    5324.0
# 249859 2022-05-16       Republic Airlines    4318.0
# 485902 2022-06-05  American Airlines Inc.    2977.0
# 190829 2022-03-26  American Airlines Inc.    2934.0
# ...           ...                     ...       ...
# 590535 2022-03-31       Republic Airlines       NaN
# 590537 2022-03-31       Republic Airlines       NaN
# 590538 2022-03-17       Republic Airlines       NaN
# 590540 2022-03-25       Republic Airlines       NaN
# 590541 2022-03-07       Republic Airlines       NaN
#
# [4078318 rows x 3 columns]

# %%
# Sort the selected columns 'FlightDate', 'Airline', 'ArrDelay' by 'ArrDelay' column in descending order,
# and reset the index
df[['FlightDate', 'Airline', 'ArrDelay']].sort_values('ArrDelay', ascending=False).reset_index(drop=True)
# Out:
#         FlightDate                 Airline  ArrDelay
# 0       2022-05-23       Republic Airlines    7232.0
# 1       2022-06-18               Envoy Air    5324.0
# 2       2022-05-16       Republic Airlines    4318.0
# 3       2022-06-05  American Airlines Inc.    2977.0
# 4       2022-03-26  American Airlines Inc.    2934.0
# ...            ...                     ...       ...
# 4078313 2022-03-31       Republic Airlines       NaN
# 4078314 2022-03-31       Republic Airlines       NaN
# 4078315 2022-03-17       Republic Airlines       NaN
# 4078316 2022-03-25       Republic Airlines       NaN
# 4078317 2022-03-07       Republic Airlines       NaN
#
# [4078318 rows x 3 columns]

# %%
# Sort the selected columns 'FlightDate', 'Airline', 'ArrDelay' by index in ascending order
df[['FlightDate', 'Airline', 'ArrDelay']].sort_index(ascending=True)
# Out:
#        FlightDate                                    Airline  ArrDelay
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 0      2022-05-03                                Comair Inc.       1.0
# 0      2022-01-06                       Delta Air Lines Inc.       NaN
# 0      2022-07-19                                Comair Inc.     -29.0
# 0      2022-03-08                       Delta Air Lines Inc.     -14.0
# ...           ...                                        ...       ...
# 618785 2022-07-01                          Republic Airlines      18.0
# 618786 2022-07-01                          Republic Airlines     -25.0
# 618787 2022-07-01                          Republic Airlines      20.0
# 618788 2022-07-01                          Republic Airlines      43.0
# 618789 2022-07-01                          Republic Airlines     183.0
#
# [4078318 rows x 3 columns]

# %%
# Sort the selected columns 'FlightDate', 'Airline', 'ArrDelay' by index in descending order
df[['FlightDate', 'Airline', 'ArrDelay']].sort_index(ascending=False)
# Out:
#        FlightDate                                    Airline  ArrDelay
# 618789 2022-07-01                          Republic Airlines     183.0
# 618788 2022-07-01                          Republic Airlines      43.0
# 618787 2022-07-01                          Republic Airlines      20.0
# 618786 2022-07-01                          Republic Airlines     -25.0
# 618785 2022-07-01                          Republic Airlines      18.0
# ...           ...                                        ...       ...
# 0      2022-03-08                       Delta Air Lines Inc.     -14.0
# 0      2022-07-19                                Comair Inc.     -29.0
# 0      2022-01-06                       Delta Air Lines Inc.       NaN
# 0      2022-05-03                                Comair Inc.       1.0
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
#
# [4078318 rows x 3 columns]

# %% [markdown]
# # Handling Missing Data

# %%
# Count the number of missing values in each column 'FlightDate', 'Airline', 'ArrDelay'
df[['FlightDate', 'Airline', 'ArrDelay']].isna().sum()
# Out:
# FlightDate         0
# Airline            0
# ArrDelay      133402
# dtype: int64

# %%
# Drop rows with missing values in the 'ArrDelay' column
df[['FlightDate', 'Airline', 'ArrDelay']].dropna(subset=['ArrDelay'])
# Out:
#        FlightDate                                    Airline  ArrDelay
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -1.0
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -3.0
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -18.0
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.       6.0
# ...           ...                                        ...       ...
# 590532 2022-03-31                          Republic Airlines     207.0
# 590533 2022-03-31                          Republic Airlines     201.0
# 590534 2022-03-31                          Republic Airlines     180.0
# 590536 2022-03-19                          Republic Airlines     135.0
# 590539 2022-03-08                          Republic Airlines     381.0
#
# [3944916 rows x 3 columns]

# %%
# Count the number of missing values in each column after dropping rows with missing values in the 'ArrDelay' column
df[['FlightDate', 'Airline', 'ArrDelay']].dropna(subset=['ArrDelay']).isna().sum()
# Out:
# FlightDate    0
# Airline       0
# ArrDelay      0
# dtype: int64

# %%
# Fill missing values in the 'ArrDelay' column with 0
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(0)
# Out:
#        FlightDate                                    Airline  ArrDelay
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -17.0
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -1.0
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.      -3.0
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.     -18.0
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.       6.0
# ...           ...                                        ...       ...
# 590537 2022-03-31                          Republic Airlines       0.0
# 590538 2022-03-17                          Republic Airlines       0.0
# 590539 2022-03-08                          Republic Airlines     381.0
# 590540 2022-03-25                          Republic Airlines       0.0
# 590541 2022-03-07                          Republic Airlines       0.0
#
# [4078318 rows x 3 columns]

# %%
# Count the number of missing values in each column after filling missing values in the 'ArrDelay' column with 0
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(0).isna().sum()
# Out:
# FlightDate    0
# Airline       0
# ArrDelay      0
# dtype: int64

# %%
# Fill missing values in the 'ArrDelay' column with the mean of the column
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(df['ArrDelay'].mean())
# Out:
#        FlightDate                                    Airline    ArrDelay
# 0      2022-04-04  Commutair Aka Champlain Enterprises, Inc.  -17.000000
# 1      2022-04-04  Commutair Aka Champlain Enterprises, Inc.   -1.000000
# 2      2022-04-04  Commutair Aka Champlain Enterprises, Inc.   -3.000000
# 3      2022-04-04  Commutair Aka Champlain Enterprises, Inc.  -18.000000
# 4      2022-04-04  Commutair Aka Champlain Enterprises, Inc.    6.000000
# ...           ...                                        ...         ...
# 590537 2022-03-31                          Republic Airlines    7.528486
# 590538 2022-03-17                          Republic Airlines    7.528486
# 590539 2022-03-08                          Republic Airlines  381.000000
# 590540 2022-03-25                          Republic Airlines    7.528486
# 590541 2022-03-07                          Republic Airlines    7.528486
#
# [4078318 rows x 3 columns]

# %%
# Count the number of missing values in each column after filling missing values in the 'ArrDelay' column with the mean
df[['FlightDate', 'Airline', 'ArrDelay']].fillna(df['ArrDelay'].mean()).isna().sum()
# Out:
# FlightDate    0
# Airline       0
# ArrDelay      0
# dtype: int64

# %% [markdown]
# # Combining Data

# %%
# Create DataFrame df1 with rows where Airline is "Southwest Airlines Co."
df1 = df.query('Airline == "Southwest Airlines Co."').copy()

# Create DataFrame df2 with rows where Airline is "Delta Air Lines Inc."
df2 = df.query('Airline == "Delta Air Lines Inc."').copy()

# Stack df1 and df2 vertically
df_stack = pd.concat([df1, df2])

# %%
# Reset index for df1 and df2
df1 = df1.reset_index(drop=True)
df2 = df2.reset_index(drop=True)

# Concatenate df1 and df2 horizontally
df_side = pd.concat([df1, df2], axis=1)

# %%
# Display shapes of original DataFrame df, df2, stacked DataFrame df_stack, and side-by-side DataFrame df_side
df.shape, df2.shape, df_stack.shape , df_side.shape
# Out:
# ((4078318, 63), (512114, 63), (1244039, 63), (731925, 126))

# %% [markdown]
# # Merge Data

# %% [markdown]
# ## df.merge()

# %%
# Group by 'Airline' and 'FlightDate' and calculate the mean of 'DepDelay'
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()

# Group by 'Airline' and 'FlightDate' and calculate the mean of 'ArrDelay'
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
# Merge df1 and df2 using the default inner join
df_inner = df1.merge(df2)

# Merge df1 and df2 using inner join explicitly
df_inner_explicit = df1.merge(df2, how='inner')

# Merge df1 and df2 using left join
df_left = df1.merge(df2, how='left')

# Merge df1 and df2 using right join
df_right = df1.merge(df2, how='right')

# Merge df1 and df2 using outer join
df_outer = df1.merge(df2, how='outer')

# %% [markdown]
# # pd.merge()

# %%
# Group by 'Airline' and 'FlightDate' and calculate the mean of 'DepDelay'
df1 = df.groupby(['Airline', 'FlightDate'])[['DepDelay']].mean().reset_index()

# Group by 'Airline' and 'FlightDate' and calculate the mean of 'ArrDelay'
df2 = df.groupby(['Airline', 'FlightDate'])[['ArrDelay']].mean().reset_index()

# %%
# Merge df1 and df2 using the default inner join
pd.merge(df1, df2)

# Merge df1 and df2 on specified columns
pd.merge(df1, df2, on=['Airline', 'FlightDate'])

# Merge df1 and df2 on 'Airline' column with suffixes for disambiguation
pd.merge(df1, df2, on='Airline', suffixes=('_dep', '_arr'))

# Merge df1 and df2 using left_on and right_on parameters
pd.merge(df1, df2, left_on=['Airline'], right_on=['Airline'])
# Out:
#                             Airline FlightDate_x   DepDelay FlightDate_y  \
# 0       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-01
# 1       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-02
# 2       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-03
# 3       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-04
# 4       Air Wisconsin Airlines Corp   2022-01-01   8.784810   2022-01-05
# ...                             ...          ...        ...          ...
# 943819        United Air Lines Inc.   2022-07-31  12.688534   2022-07-27
# 943820        United Air Lines Inc.   2022-07-31  12.688534   2022-07-28
# 943821        United Air Lines Inc.   2022-07-31  12.688534   2022-07-29
# 943822        United Air Lines Inc.   2022-07-31  12.688534   2022-07-30
# 943823        United Air Lines Inc.   2022-07-31  12.688534   2022-07-31
#
#          ArrDelay
# 0        5.717949
# 1       36.641176
# 2       36.525316
# ...

# %% [markdown]
# # Done!!!
