# %% [markdown]
# # Conditional probability
#
# Conditional probability is the probability of an event occurring given that another event has already occurred. It quantifies the likelihood of an event given some additional information about the outcome of a related event.
#
# ![image.png](attachment:001fe23d-c918-482d-b87b-f3d908d5ccdd.png)
#
# ![image.png](attachment:7472d441-bc1e-4788-9e94-810252869e29.png)
